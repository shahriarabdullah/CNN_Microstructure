# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriarabdullah/CNN_Microstructure/blob/main/GoogleColab/CNN_Microstructure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download dataset from my GitHub
# !wget https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/test.zip
# !wget https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/train.zip
# Out:
# --2022-01-31 14:42:59--  https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/test.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/test.zip [following]
# --2022-01-31 14:42:59--  https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/test.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 562839 (550K) [application/zip]
# Saving to: ‘test.zip’
#
# test.zip            100%[===================>] 549.65K  --.-KB/s    in 0.04s
#
# 2022-01-31 14:42:59 (12.5 MB/s) - ‘test.zip’ saved [562839/562839]
#
# --2022-01-31 14:42:59--  https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/train.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/train.zip [following]
# --2022-01-31 14:43:00--  https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/train.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2153295 (2.1M) [application/zip]
# Saving to: ‘train.zip’
#
# train.zip           100%[===================>]   2.05M  --.-KB/s    in 0.06s
#
# 2022-01-31 14:43:00 (32.1 MB/s) - ‘train.zip’ saved [2153295/2153295]

# %%
# Extract from ZIP
# !unzip "train.zip" -d "/content/"
# !unzip "test.zip" -d "/content/"
# Out:
# Archive:  train.zip
#    creating: /content/train/
#    creating: /content/train/coarse/
#   inflating: /content/train/coarse/24.png
#   inflating: /content/train/coarse/24m.png
#   inflating: /content/train/coarse/24mm.png
#   inflating: /content/train/coarse/25.png
#   inflating: /content/train/coarse/25m.png
#   inflating: /content/train/coarse/25mm.png
#   inflating: /content/train/coarse/26.png
#   inflating: /content/train/coarse/26m.png
#   inflating: /content/train/coarse/26mm.png
#   inflating: /content/train/coarse/27.png
#   inflating: /content/train/coarse/27m.png
#   inflating: /content/train/coarse/27mm.png
#   inflating: /content/train/coarse/28.png
#   inflating: /content/train/coarse/28m.png
#   inflating: /content/train/coarse/28mm.png
#   inflating: /content/train/coarse/29.png
#   inflating: /content/train/coarse/29m.png
#   inflating: /content/train/coarse/29mm.png
#   inflating: /content/train/coarse/30.png
#   inflating: /content/train/coarse/30m.png
#   inflating: /content/train/coarse/30mm.png
#   inflating: /content/train/coarse/31.png
#   inflating: /content/train/coarse/31m.png
#   inflating: /content/train/coarse/31mm.png
#   inflating: /content/train/coarse/32.png
#   inflating: /content/train/coarse/32m.png
#   inflating: /content/train/coarse/32mm.png
#   inflating: /content/train/coarse/33.png
#   inflating: /content/train/coarse/33m.png
#   inflating: /content/train/coarse/33mm.png
#    creating: /content/train/fine/
#   inflating: /content/train/fine/10.png
#   inflating: /content/train/fine/10m.png
#   inflating: /content/train/fine/10mm.png
#   inflating: /content/train/fine/11.png
#   inflating: /content/train/fine/11m.png
#   inflating: /content/train/fine/11mm.png
#   inflating: /content/train/fine/12.png
#   inflating: /content/train/fine/12m.png
#   inflating: /content/train/fine/12mm.png
#   inflating: /content/train/fine/13.png
#   inflating: /content/train/fine/13m.png
#   inflating: /content/train/fine/13mm.png
#   inflating: /content/train/fine/14.png
#   inflating: /content/train/fine/14m.png
#   inflating: /content/train/fine/14mm.png
#   inflating: /content/train/fine/5.png
#   inflating: /content/train/fine/5m.png
#   inflating: /content/train/fine/5mm.png
#   inflating: /content/train/fine/6.png
#   inflating: /content/train/fine/6m.png
#   inflating: /content/train/fine/6mm.png
#   inflating: /content/train/fine/7.png
#   inflating: /content/train/fine/7m.png
#   inflating: /content/train/fine/7mm.png
#   inflating: /content/train/fine/8.png
#   inflating: /content/train/fine/8m.png
#   inflating: /content/train/fine/8mm.png
#   inflating: /content/train/fine/9.png
#   inflating: /content/train/fine/9m.png
#   inflating: /content/train/fine/9mm.png
# Archive:  test.zip
#    creating: /content/test/
#    creating: /content/test/coarse/
#   inflating: /content/test/coarse/22.png
#   inflating: /content/test/coarse/22m.png
#   inflating: /content/test/coarse/22mm.png
#   inflating: /content/test/coarse/23.png
#   inflating: /content/test/coarse/23m.png
#   inflating: /content/test/coarse/23mm.png
#   inflating: /content/test/coarse/42.png
#   inflating: /content/test/coarse/42m.png
#   inflating: /content/test/coarse/42mm.png
#    creating: /content/test/fine/
#   inflating: /content/test/fine/15.png
#   inflating: /content/test/fine/15m.png
#   inflating: /content/test/fine/15mm.png
#   inflating: /content/test/fine/16.png
#   inflating: /content/test/fine/16m.png
#   inflating: /content/test/fine/16mm.png
#   inflating: /content/test/fine/7.png
#   inflating: /content/test/fine/7m.png
#   inflating: /content/test/fine/7mm.png

# %%
# Download samples for prediction
# !wget https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/c1.png
# !wget https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/c2.png
# !wget https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/f1.png
# !wget https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/f2.png
# Out:
# --2022-01-31 14:43:17--  https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/c1.png
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/c1.png [following]
# --2022-01-31 14:43:18--  https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/c1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19490 (19K) [image/png]
# Saving to: ‘c1.png’
#
# c1.png              100%[===================>]  19.03K  --.-KB/s    in 0s
#
# 2022-01-31 14:43:18 (38.8 MB/s) - ‘c1.png’ saved [19490/19490]
#
# --2022-01-31 14:43:18--  https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/c2.png
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/c2.png [following]
# --2022-01-31 14:43:19--  https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/c2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17891 (17K) [image/png]
# Saving to: ‘c2.png’
#
# c2.png              100%[===================>]  17.47K  --.-KB/s    in 0s
#
# 2022-01-31 14:43:19 (66.5 MB/s) - ‘c2.png’ saved [17891/17891]
#
# --2022-01-31 14:43:19--  https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/f1.png
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/f1.png [following]
# --2022-01-31 14:43:20--  https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/f1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95938 (94K) [image/png]
# Saving to: ‘f1.png’
#
# f1.png              100%[===================>]  93.69K  --.-KB/s    in 0.01s
#
# 2022-01-31 14:43:20 (6.52 MB/s) - ‘f1.png’ saved [95938/95938]
#
# --2022-01-31 14:43:20--  https://github.com/shahriarabdullah/CNN_Microstructure/raw/main/GoogleColab/f2.png
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/f2.png [following]
# --2022-01-31 14:43:21--  https://raw.githubusercontent.com/shahriarabdullah/CNN_Microstructure/main/GoogleColab/f2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63375 (62K) [image/png]
# Saving to: ‘f2.png’
#
# f2.png              100%[===================>]  61.89K  --.-KB/s    in 0.01s
#
# 2022-01-31 14:43:21 (5.26 MB/s) - ‘f2.png’ saved [63375/63375]

# %%
# Train model

import tensorflow as tf
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import pandas as pd

tf.random.set_seed(45)

train = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)
test = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory("/content/train/",
                                          target_size=(432,288),
                                          batch_size = 2,
                                          class_mode = 'binary')
                                         
test_dataset = test.flow_from_directory("/content/test/",
                                          target_size=(432,288),
                                          batch_size =2,
                                          class_mode = 'binary')

test_dataset.class_indices

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(8,(3,3),activation='relu',input_shape=(432,288,3)),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(16,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')

])	

model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(),
    metrics=["accuracy"]
)


history=model.fit_generator(train_dataset,
         steps_per_epoch = 12,
         epochs = 10,
         validation_data = test_dataset
         )

model.save("trained_model.h5")

pd.DataFrame(history.history).plot()
# Out:
# Found 60 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:52: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/10
# 12/12 [==============================] - 4s 235ms/step - loss: 0.6221 - accuracy: 0.6250 - val_loss: 0.6223 - val_accuracy: 0.5000
# Epoch 2/10
# 12/12 [==============================] - 3s 218ms/step - loss: 0.3794 - accuracy: 0.7500 - val_loss: 0.5293 - val_accuracy: 0.7222
# Epoch 3/10
# 12/12 [==============================] - 3s 215ms/step - loss: 0.4030 - accuracy: 0.7917 - val_loss: 0.2776 - val_accuracy: 1.0000
# Epoch 4/10
# 12/12 [==============================] - 3s 213ms/step - loss: 0.3026 - accuracy: 0.9167 - val_loss: 0.1959 - val_accuracy: 1.0000
# Epoch 5/10
# 12/12 [==============================] - 3s 219ms/step - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 1.0000
# Epoch 6/10
# 12/12 [==============================] - 3s 216ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 1.0000
# Epoch 7/10
# 12/12 [==============================] - 3s 216ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 8/10
# 12/12 [==============================] - 3s 216ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 9/10
# 12/12 [==============================] - 3s 217ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0225 - val_accuracy: 1.0000
# Epoch 10/10
# 12/12 [==============================] - 3s 218ms/step - loss: 9.6989e-04 - accuracy: 1.0000 - val_loss: 0.0220 - val_accuracy: 1.0000

# %%
# Function for prediction
def predict_ms(filename):
    img = tf.keras.preprocessing.image.load_img(filename,target_size=(432,288))
    
    plt.figure(figsize=(3,7))
    plt.imshow(img)
    
    Y = tf.keras.preprocessing.image.img_to_array(img)
    
    X = np.expand_dims(Y,axis=0)
    val = model.predict(X)
    print(val)
    if val == 1:
        
        plt.xlabel("FINE MICROSTRUCTURE",fontsize=20)
        
    
    elif val == 0:
        
        plt.xlabel("COARSE MICROSTRUCTURE",fontsize=20)

# %%
# Run the following code to predict result

# predict_ms("c1.png") # Output should be COARSE MICROSTRUCTURE

predict_ms("f1.png")
# Out:
# [[1.]]
